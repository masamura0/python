# %%
import pandas_datareader.data as pdr
df = pdr.DataReader("9434.JP", "stooq")
df
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2022-02-10  1453.50  1455.50  1449.00  1451.50    8612200
# 2022-02-09  1456.00  1458.00  1445.50  1451.00   14379300
# 2022-02-08  1448.50  1462.00  1441.00  1454.50   17920500
# 2022-02-07  1443.00  1446.50  1439.00  1441.00   11911100
# 2022-02-04  1446.50  1453.50  1436.00  1441.50   11807700
# ...             ...      ...      ...      ...        ...
# 2018-12-26  1086.74  1099.26  1076.70  1090.07   14494424
# 2018-12-25  1092.57  1103.44  1036.57  1062.49   44159036
# 2018-12-21  1069.17  1149.43  1065.84  1100.10   77805144
# 2018-12-20   988.92  1095.08   983.07  1083.37  127235356
# 2018-12-19  1222.99  1223.83  1071.68  1071.68  324780602
#
# [762 rows x 5 columns]

# %%
import pandas as pd
df = pd.read_csv('9434.T.csv')
df
# Out:
#            Date    Open    High     Low   Close    Adj Close    Volume
# 0    2021-02-15  1437.0  1437.5  1429.0  1435.0  1355.796875   7055600
# 1    2021-02-16  1440.0  1456.5  1440.0  1455.0  1374.692871  13477300
# 2    2021-02-17  1456.0  1471.0  1446.0  1463.0  1382.251343  11835500
# 3    2021-02-18  1463.0  1464.5  1442.0  1442.5  1362.882813  10200800
# 4    2021-02-19  1440.0  1442.0  1431.0  1436.0  1356.741699   7856800
# ..          ...     ...     ...     ...     ...          ...       ...
# 240  2022-02-07  1443.0  1446.5  1439.0  1441.0  1441.000000  11911100
# 241  2022-02-08  1448.5  1462.0  1441.0  1454.5  1454.500000  17920500
# 242  2022-02-09  1456.0  1458.0  1445.5  1451.0  1451.000000  14379300
# 243  2022-02-10  1453.5  1455.5  1449.0  1451.5  1451.500000   8612200
# 244  2022-02-14  1446.0  1446.5  1435.5  1438.0  1438.000000   5704100
#
# [245 rows x 7 columns]

# %%
import pandas_datareader.data as pdr

df = pdr.DataReader("9434.JP", "stooq")
df.index
# Out:
# DatetimeIndex(['2022-02-10', '2022-02-09', '2022-02-08', '2022-02-07',
#                '2022-02-04', '2022-02-03', '2022-02-02', '2022-02-01',
#                '2022-01-31', '2022-01-28',
#                ...
#                '2019-01-08', '2019-01-07', '2019-01-04', '2018-12-28',
#                '2018-12-27', '2018-12-26', '2018-12-25', '2018-12-21',
#                '2018-12-20', '2018-12-19'],
#               dtype='datetime64[ns]', name='Date', length=762, freq=None)

# %%
import pandas_datareader.data as pdr

df = pdr.DataReader("9434.JP", "stooq").sort_index()
df
# Out:
#                Open     High      Low    Close     Volume
# Date
# 2018-12-19  1222.99  1223.83  1071.68  1071.68  324780602
# 2018-12-20   988.92  1095.08   983.07  1083.37  127235356
# 2018-12-21  1069.17  1149.43  1065.84  1100.10   77805144
# 2018-12-25  1092.57  1103.44  1036.57  1062.49   44159036
# 2018-12-26  1086.74  1099.26  1076.70  1090.07   14494424
# ...             ...      ...      ...      ...        ...
# 2022-02-04  1446.50  1453.50  1436.00  1441.50   11807700
# 2022-02-07  1443.00  1446.50  1439.00  1441.00   11911100
# 2022-02-08  1448.50  1462.00  1441.00  1454.50   17920500
# 2022-02-09  1456.00  1458.00  1445.50  1451.00   14379300
# 2022-02-10  1453.50  1455.50  1449.00  1451.50    8612200
#
# [762 rows x 5 columns]

# %%
df["Close"]
# Out:
# Date
# 2018-12-19    1040.89
# 2018-12-20    1052.24
# 2018-12-21    1068.49
# 2018-12-25    1031.96
# 2018-12-26    1058.75
#                ...
# 2022-02-04    1400.08
# 2022-02-07    1399.59
# 2022-02-08    1412.71
# 2022-02-09    1409.31
# 2022-02-10    1409.79
# Name: Close, Length: 762, dtype: float64

# %%
df.tail()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2022-02-04  1446.5  1453.5  1436.0  1441.5  11807700
# 2022-02-07  1443.0  1446.5  1439.0  1441.0  11911100
# 2022-02-08  1448.5  1462.0  1441.0  1454.5  17920500
# 2022-02-09  1456.0  1458.0  1445.5  1451.0  14379300
# 2022-02-10  1453.5  1455.5  1449.0  1451.5   8612200

# %%
import pandas_datareader.data as pdr

def get_stock_data(code):
  df = pdr.DataReader("{}.JP".format(code), "stooq").sort_index()
  return df

# %%
df = get_stock_data(9984)
df.plot()

# %%
df["Close"].plot()

# %%
import datetime as dt

df[df.index >= dt.datetime(2022,1,1)].head()
# Out:
#                Open     High      Low    Close    Volume
# Date
# 2022-01-04  5550.72  5551.72  5398.34  5460.09  14158694
# 2022-01-05  5418.26  5492.96  5373.44  5398.34  11627978
# 2022-01-06  5370.45  5393.36  5279.81  5350.53  16180174
# 2022-01-07  5418.26  5577.62  5396.34  5467.06  20624739
# 2022-01-11  5403.32  5418.26  5309.69  5338.58  14783290

# %%
df[df.index >= dt.datetime(2022,1,1)]["Close"].plot()

# %%
df[dt.datetime(2022,1,1):dt.datetime(2022,12,31)]["Close"].plot()

# %%
import pandas_datareader.data as pdr
import datetime as dt

df = pdr.DataReader("9984.JP", "stooq").sort_index()
df = df[df.index <= dt.datetime(2022,2,10)]
df
# Out:
#                Open     High      Low    Close    Volume
# Date
# 2017-05-08  4202.11  4206.47  4148.08  4194.79  16207631
# 2017-05-09  4185.05  4192.84  4151.01  4173.87   9595693
# 2017-05-10  4189.44  4239.08  4187.00  4233.74  12501361
# 2017-05-11  4287.75  4328.62  4272.17  4318.90  19325571
# 2017-05-12  4321.32  4331.06  4209.88  4212.80  18155289
# ...             ...      ...      ...      ...       ...
# 2022-02-04  5129.41  5213.08  5070.65  5193.16  17130874
# 2022-02-07  5216.07  5472.04  5200.13  5328.62  22554653
# 2022-02-08  5342.56  5384.39  5241.96  5280.81  18101453
# 2022-02-09  5328.62  5605.50  5288.78  5589.57  30944588
# 2022-02-10  5689.17  5716.06  5384.39  5461.08  28275921
#
# [1164 rows x 5 columns]

# %%
df.query("Close >= 7000").tail()
# Out:
#                Open     High      Low    Close    Volume
# Date
# 2021-09-09  6928.55  7156.89  6907.71  7073.50  26391156
# 2021-09-10  7101.30  7290.92  7030.81  7127.11  27983867
# 2021-09-13  7115.20  7164.84  6947.42  7024.86  17102114
# 2021-11-16  6932.18  7119.43  6885.37  7084.57  19016210
# 2021-11-17  7141.34  7188.15  7084.57  7103.49  15881881

# %%
df.query("High - Low >= 300").tail()
# Out:
#                Open     High      Low    Close    Volume
# Date
# 2022-01-26  4949.14  5237.98  4924.24  5135.39  21684876
# 2022-01-27  5100.53  5149.34  4633.41  4673.25  38173383
# 2022-01-31  4691.17  5098.54  4674.24  4990.97  23447422
# 2022-02-09  5328.62  5605.50  5288.78  5589.57  30944588
# 2022-02-10  5689.17  5716.06  5384.39  5461.08  28275921

# %%
import pandas as pd

df = pd.read_csv('9434.T.csv', index_col=0)
df.head()
# Out:
#               Open    High     Low   Close    Adj Close    Volume
# Date
# 2021-02-15  1437.0  1437.5  1429.0  1435.0  1355.796875   7055600
# 2021-02-16  1440.0  1456.5  1440.0  1455.0  1374.692871  13477300
# 2021-02-17  1456.0  1471.0  1446.0  1463.0  1382.251343  11835500
# 2021-02-18  1463.0  1464.5  1442.0  1442.5  1362.882813  10200800
# 2021-02-19  1440.0  1442.0  1431.0  1436.0  1356.741699   7856800
